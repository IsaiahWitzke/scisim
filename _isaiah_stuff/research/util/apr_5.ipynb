# %%
import sys
# caution: path[0] is reserved for script path (or '' in REPL)
sys.path.insert(1, '/home/isaiah/scisim/_isaiah_stuff/research')
sys.path.insert(1, '/home/isaiah/scisim/_isaiah_stuff/research/solvers')

import data_import
import pandas as pd
import numpy as np
from solvers.policy_iter_v3 import PolicyIterationV3
from solvers.policy_iter_v2 import PolicyIterationV2
from solvers.policy_iter import PolicyIteration
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [10, 5]

# %%
pd_data_5: pd.DataFrame = data_import.read_files_to_pd_dataframe(
    [f"../outs/5_by_5_grid/itr_{i}.xml.out" for i in range(50)]
)
# pd_data_6: pd.DataFrame = data_import.read_files_to_pd_dataframe(
#     [f"../outs/6_by_6_grid/itr_{i}.xml.out" for i in range(50)]
# )
# pd_data_7: pd.DataFrame = data_import.read_files_to_pd_dataframe(
#     [f"../outs/7_by_7_grid/itr_{i}.xml.out" for i in range(50)]
# )
# pd_data_8: pd.DataFrame = data_import.read_files_to_pd_dataframe(
#     [f"../outs/8_by_8_grid/itr_{i}.xml.out" for i in range(50)]
# )

# %%
# main_df = pd.concat([pd_data_5, pd_data_6, pd_data_7, pd_data_8], ignore_index=True)
main_df = pd_data_5
main_df['pi_solver_v3'] = [
    PolicyIterationV3(main_df['Q'][i], main_df['b'][i], name=main_df['f_name'][i])
    for i in range(len(main_df))
]
main_df['pi_solver_v2'] = [
    PolicyIterationV2(main_df['Q'][i], main_df['b'][i], name=main_df['f_name'][i])
    for i in range(len(main_df))
]
main_df['pi_solver_v1'] = [
    PolicyIteration(main_df['Q'][i], main_df['b'][i], name=main_df['f_name'][i])
    for i in range(len(main_df))
]

# %%
for pi_solver in main_df['pi_solver_v1']:
    pi_solver.solve()
# Out:
# ../outs/5_by_5_grid/itr_0.xml.out: DIVERGED AT ITERATION 34
# ../outs/5_by_5_grid/itr_1.xml.out: CONVERGED IN 8 ITERATIONS
# ../outs/5_by_5_grid/itr_2.xml.out: CONVERGED IN 5 ITERATIONS
# ../outs/5_by_5_grid/itr_3.xml.out: CONVERGED IN 13 ITERATIONS
# ../outs/5_by_5_grid/itr_4.xml.out: CONVERGED IN 8 ITERATIONS
# ../outs/5_by_5_grid/itr_5.xml.out: CONVERGED IN 3 ITERATIONS
# ../outs/5_by_5_grid/itr_6.xml.out: CONVERGED IN 6 ITERATIONS
# ../outs/5_by_5_grid/itr_7.xml.out: CONVERGED IN 9 ITERATIONS
# ../outs/5_by_5_grid/itr_8.xml.out: CONVERGED IN 19 ITERATIONS
# ../outs/5_by_5_grid/itr_9.xml.out: CONVERGED IN 9 ITERATIONS
# ../outs/5_by_5_grid/itr_10.xml.out: DIVERGED AT ITERATION 13
# ../outs/5_by_5_grid/itr_11.xml.out: DIVERGED AT ITERATION 57
# ../outs/5_by_5_grid/itr_12.xml.out: DIVERGED AT ITERATION 8
# ../outs/5_by_5_grid/itr_13.xml.out: CONVERGED IN 14 ITERATIONS
# ../outs/5_by_5_grid/itr_14.xml.out: CONVERGED IN 23 ITERATIONS
# ../outs/5_by_5_grid/itr_15.xml.out: CONVERGED IN 26 ITERATIONS
# ../outs/5_by_5_grid/itr_16.xml.out: DIVERGED AT ITERATION 9
# ../outs/5_by_5_grid/itr_17.xml.out: DIVERGED AT ITERATION 10
# ../outs/5_by_5_grid/itr_18.xml.out: CONVERGED IN 2 ITERATIONS
# ../outs/5_by_5_grid/itr_19.xml.out: CONVERGED IN 4 ITERATIONS
# ../outs/5_by_5_grid/itr_20.xml.out: CONVERGED IN 12 ITERATIONS
# ../outs/5_by_5_grid/itr_21.xml.out: CONVERGED IN 85 ITERATIONS
# ../outs/5_by_5_grid/itr_22.xml.out: CONVERGED IN 4 ITERATIONS
# ../outs/5_by_5_grid/itr_23.xml.out: CONVERGED IN 3 ITERATIONS
# ../outs/5_by_5_grid/itr_24.xml.out: DIVERGED AT ITERATION 19
# ../outs/5_by_5_grid/itr_25.xml.out: CONVERGED IN 29 ITERATIONS
# ../outs/5_by_5_grid/itr_26.xml.out: CONVERGED IN 11 ITERATIONS
# ../outs/5_by_5_grid/itr_27.xml.out: CONVERGED IN 16 ITERATIONS
# ../outs/5_by_5_grid/itr_28.xml.out: DIVERGED AT ITERATION 8
# ../outs/5_by_5_grid/itr_29.xml.out: CONVERGED IN 7 ITERATIONS
# ../outs/5_by_5_grid/itr_30.xml.out: CONVERGED IN 31 ITERATIONS
# ../outs/5_by_5_grid/itr_31.xml.out: CONVERGED IN 29 ITERATIONS
# ../outs/5_by_5_grid/itr_32.xml.out: DIVERGED AT ITERATION 12
# ../outs/5_by_5_grid/itr_33.xml.out: CONVERGED IN 16 ITERATIONS
# ../outs/5_by_5_grid/itr_34.xml.out: CONVERGED IN 27 ITERATIONS
# ../outs/5_by_5_grid/itr_35.xml.out: CONVERGED IN 7 ITERATIONS
# ../outs/5_by_5_grid/itr_36.xml.out: CONVERGED IN 7 ITERATIONS
# ../outs/5_by_5_grid/itr_37.xml.out: CONVERGED IN 4 ITERATIONS
# ../outs/5_by_5_grid/itr_38.xml.out: DIVERGED AT ITERATION 12
# ../outs/5_by_5_grid/itr_39.xml.out: CONVERGED IN 5 ITERATIONS
# ../outs/5_by_5_grid/itr_40.xml.out: CONVERGED IN 8 ITERATIONS
# ../outs/5_by_5_grid/itr_41.xml.out: DIVERGED AT ITERATION 10
# ../outs/5_by_5_grid/itr_42.xml.out: CONVERGED IN 7 ITERATIONS
# ../outs/5_by_5_grid/itr_43.xml.out: CONVERGED IN 3 ITERATIONS
# ../outs/5_by_5_grid/itr_44.xml.out: CONVERGED IN 37 ITERATIONS
# ../outs/5_by_5_grid/itr_45.xml.out: CONVERGED IN 4 ITERATIONS
# ../outs/5_by_5_grid/itr_46.xml.out: DIVERGED AT ITERATION 9
# ../outs/5_by_5_grid/itr_47.xml.out: CONVERGED IN 13 ITERATIONS
# ../outs/5_by_5_grid/itr_48.xml.out: DIVERGED AT ITERATION 13
# ../outs/5_by_5_grid/itr_49.xml.out: DIVERGED AT ITERATION 32

# %%
for pi_solver in main_df['pi_solver_v2']:
    pi_solver.solve()
# Out:
# ../outs/5_by_5_grid/itr_0.xml.out: CONVERGED IN 41 ITERATIONS
# ../outs/5_by_5_grid/itr_1.xml.out: CONVERGED IN 9 ITERATIONS
# ../outs/5_by_5_grid/itr_2.xml.out: CONVERGED IN 6 ITERATIONS
# ../outs/5_by_5_grid/itr_3.xml.out: CONVERGED IN 14 ITERATIONS
# ../outs/5_by_5_grid/itr_4.xml.out: CONVERGED IN 9 ITERATIONS
# ../outs/5_by_5_grid/itr_5.xml.out: CONVERGED IN 4 ITERATIONS
# ../outs/5_by_5_grid/itr_6.xml.out: CONVERGED IN 7 ITERATIONS
# ../outs/5_by_5_grid/itr_7.xml.out: CONVERGED IN 10 ITERATIONS
# ../outs/5_by_5_grid/itr_8.xml.out: CONVERGED IN 20 ITERATIONS
# ../outs/5_by_5_grid/itr_9.xml.out: CONVERGED IN 10 ITERATIONS
# ../outs/5_by_5_grid/itr_10.xml.out: CONVERGED IN 41 ITERATIONS
# ../outs/5_by_5_grid/itr_11.xml.out: CONVERGED IN 73 ITERATIONS
# ../outs/5_by_5_grid/itr_12.xml.out: reached max iterations
# ../outs/5_by_5_grid/itr_13.xml.out: CONVERGED IN 15 ITERATIONS
# ../outs/5_by_5_grid/itr_14.xml.out: CONVERGED IN 24 ITERATIONS
# ../outs/5_by_5_grid/itr_15.xml.out: CONVERGED IN 27 ITERATIONS
# ../outs/5_by_5_grid/itr_16.xml.out: CONVERGED IN 20 ITERATIONS
# ../outs/5_by_5_grid/itr_17.xml.out: CONVERGED IN 26 ITERATIONS
# ../outs/5_by_5_grid/itr_18.xml.out: CONVERGED IN 3 ITERATIONS
# ../outs/5_by_5_grid/itr_19.xml.out: CONVERGED IN 5 ITERATIONS
# ../outs/5_by_5_grid/itr_20.xml.out: CONVERGED IN 13 ITERATIONS
# ../outs/5_by_5_grid/itr_21.xml.out: CONVERGED IN 86 ITERATIONS
# ../outs/5_by_5_grid/itr_22.xml.out: CONVERGED IN 5 ITERATIONS
# ../outs/5_by_5_grid/itr_23.xml.out: CONVERGED IN 4 ITERATIONS
# ../outs/5_by_5_grid/itr_24.xml.out: CONVERGED IN 33 ITERATIONS
# ../outs/5_by_5_grid/itr_25.xml.out: CONVERGED IN 30 ITERATIONS
# ../outs/5_by_5_grid/itr_26.xml.out: CONVERGED IN 12 ITERATIONS
# ../outs/5_by_5_grid/itr_27.xml.out: CONVERGED IN 17 ITERATIONS
# ../outs/5_by_5_grid/itr_28.xml.out: CONVERGED IN 15 ITERATIONS
# ../outs/5_by_5_grid/itr_29.xml.out: CONVERGED IN 8 ITERATIONS
# ../outs/5_by_5_grid/itr_30.xml.out: CONVERGED IN 32 ITERATIONS
# ../outs/5_by_5_grid/itr_31.xml.out: CONVERGED IN 30 ITERATIONS
# ../outs/5_by_5_grid/itr_32.xml.out: reached max iterations
# ../outs/5_by_5_grid/itr_33.xml.out: CONVERGED IN 17 ITERATIONS
# ../outs/5_by_5_grid/itr_34.xml.out: CONVERGED IN 28 ITERATIONS
# ../outs/5_by_5_grid/itr_35.xml.out: CONVERGED IN 8 ITERATIONS
# ../outs/5_by_5_grid/itr_36.xml.out: CONVERGED IN 8 ITERATIONS
# ../outs/5_by_5_grid/itr_37.xml.out: CONVERGED IN 5 ITERATIONS
# ../outs/5_by_5_grid/itr_38.xml.out: CONVERGED IN 23 ITERATIONS
# ../outs/5_by_5_grid/itr_39.xml.out: CONVERGED IN 6 ITERATIONS
# ../outs/5_by_5_grid/itr_40.xml.out: CONVERGED IN 9 ITERATIONS
# ../outs/5_by_5_grid/itr_41.xml.out: CONVERGED IN 31 ITERATIONS
# ../outs/5_by_5_grid/itr_42.xml.out: CONVERGED IN 8 ITERATIONS
# ../outs/5_by_5_grid/itr_43.xml.out: CONVERGED IN 4 ITERATIONS
# ../outs/5_by_5_grid/itr_44.xml.out: CONVERGED IN 38 ITERATIONS
# ../outs/5_by_5_grid/itr_45.xml.out: CONVERGED IN 5 ITERATIONS
# ../outs/5_by_5_grid/itr_46.xml.out: CONVERGED IN 29 ITERATIONS
# ../outs/5_by_5_grid/itr_47.xml.out: CONVERGED IN 14 ITERATIONS
# ../outs/5_by_5_grid/itr_48.xml.out: CONVERGED IN 39 ITERATIONS
# ../outs/5_by_5_grid/itr_49.xml.out: CONVERGED IN 130 ITERATIONS

# %%
for pi_solver in main_df['pi_solver_v3']:
    pi_solver.solve()
# Out:
# ../outs/5_by_5_grid/itr_0.xml.out: CONVERGED IN 74 ITERATIONS
# ../outs/5_by_5_grid/itr_1.xml.out: CONVERGED IN 8 ITERATIONS
# ../outs/5_by_5_grid/itr_2.xml.out: CONVERGED IN 5 ITERATIONS
# ../outs/5_by_5_grid/itr_3.xml.out: CONVERGED IN 13 ITERATIONS
# ../outs/5_by_5_grid/itr_4.xml.out: CONVERGED IN 8 ITERATIONS
# ../outs/5_by_5_grid/itr_5.xml.out: CONVERGED IN 3 ITERATIONS
# ../outs/5_by_5_grid/itr_6.xml.out: CONVERGED IN 6 ITERATIONS
# ../outs/5_by_5_grid/itr_7.xml.out: CONVERGED IN 9 ITERATIONS
# ../outs/5_by_5_grid/itr_8.xml.out: CONVERGED IN 19 ITERATIONS
# ../outs/5_by_5_grid/itr_9.xml.out: CONVERGED IN 9 ITERATIONS
# ../outs/5_by_5_grid/itr_10.xml.out: CONVERGED IN 21 ITERATIONS
# ../outs/5_by_5_grid/itr_11.xml.out: CONVERGED IN 106 ITERATIONS
# ../outs/5_by_5_grid/itr_12.xml.out: reached max iterations
# ../outs/5_by_5_grid/itr_13.xml.out: CONVERGED IN 14 ITERATIONS
# ../outs/5_by_5_grid/itr_14.xml.out: CONVERGED IN 23 ITERATIONS
# ../outs/5_by_5_grid/itr_15.xml.out: CONVERGED IN 26 ITERATIONS
# ../outs/5_by_5_grid/itr_16.xml.out: CONVERGED IN 95 ITERATIONS
# ../outs/5_by_5_grid/itr_17.xml.out: CONVERGED IN 29 ITERATIONS
# ../outs/5_by_5_grid/itr_18.xml.out: CONVERGED IN 2 ITERATIONS
# ../outs/5_by_5_grid/itr_19.xml.out: CONVERGED IN 4 ITERATIONS
# ../outs/5_by_5_grid/itr_20.xml.out: CONVERGED IN 12 ITERATIONS
# ../outs/5_by_5_grid/itr_21.xml.out: CONVERGED IN 85 ITERATIONS
# ../outs/5_by_5_grid/itr_22.xml.out: CONVERGED IN 4 ITERATIONS
# ../outs/5_by_5_grid/itr_23.xml.out: CONVERGED IN 3 ITERATIONS
# ../outs/5_by_5_grid/itr_24.xml.out: CONVERGED IN 67 ITERATIONS
# ../outs/5_by_5_grid/itr_25.xml.out: CONVERGED IN 29 ITERATIONS
# ../outs/5_by_5_grid/itr_26.xml.out: CONVERGED IN 11 ITERATIONS
# ../outs/5_by_5_grid/itr_27.xml.out: CONVERGED IN 16 ITERATIONS
# ../outs/5_by_5_grid/itr_28.xml.out: CONVERGED IN 24 ITERATIONS
# ../outs/5_by_5_grid/itr_29.xml.out: CONVERGED IN 7 ITERATIONS
# ../outs/5_by_5_grid/itr_30.xml.out: CONVERGED IN 31 ITERATIONS
# ../outs/5_by_5_grid/itr_31.xml.out: CONVERGED IN 29 ITERATIONS
# ../outs/5_by_5_grid/itr_32.xml.out: CONVERGED IN 127 ITERATIONS
# ../outs/5_by_5_grid/itr_33.xml.out: CONVERGED IN 16 ITERATIONS
# ../outs/5_by_5_grid/itr_34.xml.out: CONVERGED IN 27 ITERATIONS
# ../outs/5_by_5_grid/itr_35.xml.out: CONVERGED IN 7 ITERATIONS
# ../outs/5_by_5_grid/itr_36.xml.out: CONVERGED IN 7 ITERATIONS
# ../outs/5_by_5_grid/itr_37.xml.out: CONVERGED IN 4 ITERATIONS
# ../outs/5_by_5_grid/itr_38.xml.out: CONVERGED IN 77 ITERATIONS
# ../outs/5_by_5_grid/itr_39.xml.out: CONVERGED IN 5 ITERATIONS
# ../outs/5_by_5_grid/itr_40.xml.out: CONVERGED IN 8 ITERATIONS
# ../outs/5_by_5_grid/itr_41.xml.out: CONVERGED IN 55 ITERATIONS
# ../outs/5_by_5_grid/itr_42.xml.out: CONVERGED IN 7 ITERATIONS
# ../outs/5_by_5_grid/itr_43.xml.out: CONVERGED IN 3 ITERATIONS
# ../outs/5_by_5_grid/itr_44.xml.out: CONVERGED IN 37 ITERATIONS
# ../outs/5_by_5_grid/itr_45.xml.out: CONVERGED IN 4 ITERATIONS
# ../outs/5_by_5_grid/itr_46.xml.out: CONVERGED IN 36 ITERATIONS
# ../outs/5_by_5_grid/itr_47.xml.out: CONVERGED IN 13 ITERATIONS
# ../outs/5_by_5_grid/itr_48.xml.out: CONVERGED IN 46 ITERATIONS
# ../outs/5_by_5_grid/itr_49.xml.out: CONVERGED IN 38 ITERATIONS

# %%
def get_policy_from_ipopt(ipopt_sol: np.ndarray, tol = 1e-6):
    p = np.zeros(len(ipopt_sol))
    for i in range(len(ipopt_sol)):
        if abs(ipopt_sol[i]) > tol:
            p[i] = 1.0
    return p

def get_policy_diff(a: np.ndarray, b: np.ndarray):
    # return np.linalg.norm(a - b, 1) / len(a)
    return np.linalg.norm(a - b, 1)

def plot_convergence(type: str, trial_num: int) -> None:
    ipopt_policy = get_policy_from_ipopt(main_df['ipopt_sol'][trial_num])
    intermediate_policies = main_df[type][trial_num].intermediate_policies
    intermediate_objective = main_df[type][trial_num].intermediate_objective
    intermediate_policy_diffs = [ get_policy_diff(ip, ipopt_policy) for ip in intermediate_policies ]
    pois = main_df[type][trial_num].pois

    fig, ax1 = plt.subplots()
    ax1.set_title(type)
    color = 'tab:red'
    ax1.set_xlabel('iteration')
    ax1.set_ylabel('policy divergence from IPOPT (abs diff)', color=color)
    ax1.plot(intermediate_policy_diffs, color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
    color = 'tab:blue'
    ax2.set_ylabel('objective', color=color)  # we already handled the x-label with ax1
    ax2.plot(intermediate_objective, color=color)
    ax2.set_yscale('log')
    ax2.tick_params(axis='y', labelcolor=color)
    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    for x in pois:
        plt.axvline(x=x, color='orange')
    plt.show()

# %% [markdown]
# # Convergence plots of PI V1, V2, & V3
#
# ## takeaways:
# - v3 tiny bit better than v2 in terms of chance to converge, but slower

# %%
plot_convergence('pi_solver_v1', 0)
plot_convergence('pi_solver_v2', 0)
plot_convergence('pi_solver_v3', 0)

# %%
trial = 32
plot_convergence('pi_solver_v1', trial)
plot_convergence('pi_solver_v2', trial)
plot_convergence('pi_solver_v3', trial)

# %%
trial = 49
plot_convergence('pi_solver_v1', trial)
plot_convergence('pi_solver_v2', trial)
plot_convergence('pi_solver_v3', trial)
